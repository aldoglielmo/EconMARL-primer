# %% [markdown]
# # DQN and Double DQN with Stable-Baselines3
#
# Stable-Baselines3: https://github.com/DLR-RM/stable-baselines3
#
# Documentation: https://stable-baselines.readthedocs.io/en/master/
#
# RL Baselines3 zoo: https://github.com/DLR-RM/rl-baselines3-zoo
#
# Double Q-Learning: https://paperswithcode.com/method/double-q-learning
#
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a training framework for Reinforcement Learning (RL), using Stable Baselines3.
#
# It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# ## Introduction
#
# In this notebook, we will study DQN using Stable-Baselines3 and then see how to reduce value overestimation with double DQN.

# %% [markdown]
# ## Installation
#
# We will install master version of SB3.

# %%
# for autoformatting
# %load_ext jupyter_black

# %%
# !apt-get install ffmpeg freeglut3-dev xvfb  # For visualization

# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# zsh:1: command not found: apt-get
# Requirement already satisfied: stable-baselines3>=2.0.0a4 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.8.0a2)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.2.3)
# Requirement already satisfied: numpy<3.0,>=1.20 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.4.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.10.0)
# Requirement already satisfied: cloudpickle in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.2)
# Requirement already satisfied: pandas in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.0.1)
# Requirement already satisfied: matplotlib in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.10.8)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.0.4)
# Requirement already satisfied: filelock in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.24.3)
# Requirement already satisfied: setuptools in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2026.2.0)
# Requirement already satisfied: opencv-python in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.13.0.92)
# Requirement already satisfied: pygame in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.20.0)
# Requirement already satisfied: psutil in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (7.0.0)
# Requirement already satisfied: tqdm in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.67.3)
# Requirement already satisfied: rich in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (14.3.3)
# Requirement already satisfied: ale-py>=0.9.0 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (0.11.2)
# Requirement already satisfied: pillow in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from stable-baselines3[extra]>=2.0.0a4) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.10.2)
# Requirement already satisfied: packaging in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (7.34.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)

# %% [markdown]
# Import DQN and evaluation helper

# %%
import gymnasium as gym
import numpy as np
import torch as th
import matplotlib.pyplot as plt

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## The Mountain Car Problem
#
# In this environment, the agent must drive an underpowered car up a steep mountain road. For any given state the agent may choose to accelerate to the left, right or cease any acceleration.
#
# Source: https://github.com/Farama-Foundation/Gymnasium/blob/main/gymnasium/envs/classic_control/mountain_car.py
#
# ![mountaincar.png](data:image/png;base64,...)
#
#
#     Observation:
#         Type: Box(2)
#         Num    Observation               Min            Max
#         0      Car Position              -1.2           0.6
#         1      Car Velocity              -0.07          0.07
#     Actions:
#         Type: Discrete(3)
#         Num    Action
#         0      Accelerate to the Left
#         1      Don't accelerate
#         2      Accelerate to the Right
#         Note: This does not affect the amount of velocity affected by the
#         gravitational pull acting on the car.
#     Reward:
#          Reward of 0 is awarded if the agent reached the flag (position = 0.5)
#          on top of the mountain.
#          Reward of -1 is awarded if the position of the agent is less than 0.5.
#     Starting State:
#          The position of the car is assigned a uniform random value in
#          [-0.6 , -0.4].
#          The starting velocity of the car is always assigned to 0.
#     Episode Termination:
#          The car position is more than 0.5
#          Episode length is greater than 200

# %% [markdown]
# Create the environment

# %%
env = gym.make("MountainCar-v0", render_mode="rgb_array")

# %% [markdown]
# Create the model with tuned hyperparameters from the RL Zoo
#
# ```yaml
# MountainCar-v0:
#   n_timesteps: !!float 1.2e5
#   policy: 'MlpPolicy'
#   learning_rate: !!float 4e-3
#   batch_size: 128
#   buffer_size: 10000
#   learning_starts: 1000
#   gamma: 0.98
#   target_update_interval: 600
#   train_freq: 16
#   gradient_steps: 8
#   exploration_fraction: 0.2
#   exploration_final_eps: 0.07
#   policy_kwargs: "dict(net_arch=[256, 256])"
# ```

# %%
tensorboard_log = "data/tb/"

# %%
dqn_model = DQN(
    "MlpPolicy",
    env,
    verbose=1,
    train_freq=16,
    gradient_steps=8,
    gamma=0.99,
    exploration_fraction=0.2,
    exploration_final_eps=0.07,
    target_update_interval=600,
    learning_starts=1000,
    buffer_size=10000,
    batch_size=128,
    learning_rate=4e-3,
    policy_kwargs=dict(net_arch=[256, 256]),
    tensorboard_log=tensorboard_log,
    seed=2,
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# Evaluate the agent before training

# %%
mean_reward, std_reward = evaluate_policy(
    dqn_model,
    dqn_model.get_env(),
    deterministic=True,
    n_eval_episodes=20,
)

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-200.00 +/- 0.00

# %%
# Optional: Monitor training in tensorboard
# %load_ext tensorboard
# %tensorboard --logdir $tensorboard_log

# %% [markdown]
# We will first train the agent until convergence and then analyse the learned q-value function.

# %%
dqn_model.learn(int(1.2e5), log_interval=10)
# Out:
# Logging to data/tb/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 10       |
# |    fps              | 2958     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.97e-05 |
# |    n_updates        | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2508     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 9.68e-07 |
# |    n_updates        | 1496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 30       |
# |    fps              | 2367     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.55e-05 |
# |    n_updates        | 2496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2311     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.05e-05 |
# |    n_updates        | 3496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.612    |
# | time/               |          |
# |    episodes         | 50       |
# |    fps              | 2276     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.02e-06 |
# |    n_updates        | 4496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2239     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.81e-06 |
# |    n_updates        | 5496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    episodes         | 70       |
# |    fps              | 2217     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 2.7e-05  |
# |    n_updates        | 6496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2194     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 7.75e-06 |
# |    n_updates        | 7496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 90       |
# |    fps              | 2175     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 18000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 5.5e-06  |
# |    n_updates        | 8496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2128     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 3.1e-05  |
# |    n_updates        | 9496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.147    |
# | time/               |          |
# |    episodes         | 110      |
# |    fps              | 2111     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 22000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 7.2e-06  |
# |    n_updates        | 10496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.0709   |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2071     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 23978    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 1.08e-05 |
# |    n_updates        | 11488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 130      |
# |    fps              | 2019     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 25967    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000154 |
# |    n_updates        | 12480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1989     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 27939    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000204 |
# |    n_updates        | 13472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 150      |
# |    fps              | 1947     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 29939    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000401 |
# |    n_updates        | 14472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1925     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 31923    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0698   |
# |    n_updates        | 15464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 170      |
# |    fps              | 1912     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 33773    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000189 |
# |    n_updates        | 16384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1912     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 35684    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000899 |
# |    n_updates        | 17344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 190      |
# |    fps              | 1890     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 37559    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0238   |
# |    n_updates        | 18280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1891     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 39528    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0369   |
# |    n_updates        | 19264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 210      |
# |    fps              | 1891     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 41467    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0301   |
# |    n_updates        | 20232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1897     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 43378    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.015    |
# |    n_updates        | 21192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 230      |
# |    fps              | 1892     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 45303    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00138  |
# |    n_updates        | 22152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1893     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 47156    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00486  |
# |    n_updates        | 23080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 250      |
# |    fps              | 1889     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 48986    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00868  |
# |    n_updates        | 23992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1889     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 50863    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00674  |
# |    n_updates        | 24928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 270      |
# |    fps              | 1892     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 52708    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.011    |
# |    n_updates        | 25856    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1895     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 54555    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0179   |
# |    n_updates        | 26776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 290      |
# |    fps              | 1889     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 56384    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0287   |
# |    n_updates        | 27688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1892     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 57966    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0224   |
# |    n_updates        | 28480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 310      |
# |    fps              | 1895     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 59824    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0272   |
# |    n_updates        | 29408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1897     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 61603    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0983   |
# |    n_updates        | 30304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 330      |
# |    fps              | 1895     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 63254    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0861   |
# |    n_updates        | 31128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1898     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 65003    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.072    |
# |    n_updates        | 32000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 350      |
# |    fps              | 1899     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 66708    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0791   |
# |    n_updates        | 32856    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1902     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 68432    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.103    |
# |    n_updates        | 33712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 370      |
# |    fps              | 1903     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 70038    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0549   |
# |    n_updates        | 34520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1905     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 71637    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0739   |
# |    n_updates        | 35320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 390      |
# |    fps              | 1905     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 73146    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0847   |
# |    n_updates        | 36072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1906     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 74690    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0873   |
# |    n_updates        | 36848    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 410      |
# |    fps              | 1908     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 76365    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0976   |
# |    n_updates        | 37680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1909     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 77901    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0804   |
# |    n_updates        | 38448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 430      |
# |    fps              | 1910     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 79209    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.242    |
# |    n_updates        | 39104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1910     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 80587    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.151    |
# |    n_updates        | 39792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 450      |
# |    fps              | 1911     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 81932    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.146    |
# |    n_updates        | 40464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | -148     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1912     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 83215    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.146    |
# |    n_updates        | 41104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -146     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 470      |
# |    fps              | 1913     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 84665    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.259    |
# |    n_updates        | 41832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1912     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 85958    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.186    |
# |    n_updates        | 42480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | -141     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 490      |
# |    fps              | 1909     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 87256    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.213    |
# |    n_updates        | 43128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | -140     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1910     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 88674    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.228    |
# |    n_updates        | 43840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | -138     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 510      |
# |    fps              | 1910     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 90190    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.169    |
# |    n_updates        | 44592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 1912     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 91540    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.143    |
# |    n_updates        | 45272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 530      |
# |    fps              | 1913     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 92842    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.17     |
# |    n_updates        | 45920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 1913     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 94086    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.173    |
# |    n_updates        | 46544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 550      |
# |    fps              | 1914     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 95247    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.16     |
# |    n_updates        | 47120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 1915     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 96412    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.184    |
# |    n_updates        | 47704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 570      |
# |    fps              | 1912     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 97580    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.129    |
# |    n_updates        | 48288    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 1909     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 98779    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.119    |
# |    n_updates        | 48888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -126     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 590      |
# |    fps              | 1899     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 99831    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0959   |
# |    n_updates        | 49416    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -123     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 1899     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 100978   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.15     |
# |    n_updates        | 49992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 610      |
# |    fps              | 1898     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 102156   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.136    |
# |    n_updates        | 50576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 1899     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 103369   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.151    |
# |    n_updates        | 51184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 630      |
# |    fps              | 1900     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 104597   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0908   |
# |    n_updates        | 51800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 1901     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 105663   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.128    |
# |    n_updates        | 52328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | -116     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 650      |
# |    fps              | 1899     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 106804   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.136    |
# |    n_updates        | 52904    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 1899     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 108074   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.14     |
# |    n_updates        | 53536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 670      |
# |    fps              | 1900     |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 109332   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.307    |
# |    n_updates        | 54168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -118     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 1901     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 110529   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.189    |
# |    n_updates        | 54768    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 690      |
# |    fps              | 1902     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 111838   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.126    |
# |    n_updates        | 55416    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 1902     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 113008   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.114    |
# |    n_updates        | 56000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 710      |
# |    fps              | 1903     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 114126   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.131    |
# |    n_updates        | 56560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | -121     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 1903     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 115508   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.125    |
# |    n_updates        | 57256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 730      |
# |    fps              | 1904     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 116639   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.124    |
# |    n_updates        | 57816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | -121     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 1906     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 117743   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.15     |
# |    n_updates        | 58368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | -122     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 750      |
# |    fps              | 1906     |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 118967   |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.185    |
# |    n_updates        | 58984    |
# ----------------------------------

# %% [markdown]
# Evaluate after training, the mean episodic reward should have improved.

# %%
mean_reward, std_reward = evaluate_policy(dqn_model, dqn_model.get_env(), deterministic=True, n_eval_episodes=20)

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-110.85 +/- 10.33

# %% [markdown]
# ### Prepare video recording

# %%
# Set up fake display; otherwise rendering will fail
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'
# Out:
# _XSERVTransmkdir: ERROR: euid != 0,directory /tmp/.X11-unix will not be created.
# _XSERVTransSocketUNIXCreateListener: mkdir(/tmp/.X11-unix) failed, errno = 2
# _XSERVTransMakeAllCOTSServerListeners: failed to create listener for local
# (EE)
# Fatal server error:
# (EE) Cannot establish any listening sockets - Make sure an X server isn't already running(EE)

# %%
import base64
from pathlib import Path

from IPython import display as ipythondisplay


def show_videos(video_path="", prefix=""):
    """
    Taken from https://github.com/eleurent/highway-env

    :param video_path: (str) Path to the folder containing videos
    :param prefix: (str) Filter the video, showing only the only starting with this prefix
    """
    html = []
    for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %% [markdown]
# We will record a video using the [VecVideoRecorder](https://stable-baselines.readthedocs.io/en/master/guide/vec_envs.html#vecvideorecorder) wrapper, you will learn about those wrapper in the next notebook.

# %%
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv


def record_video(
    env_id,
    model,
    video_length=500,
    prefix="",
    video_folder="videos/",
):
    """
    :param env_id: (str)
    :param model: (RL model)
    :param video_length: (int)
    :param prefix: (str)
    :param video_folder: (str)
    """
    eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])
    # Start the video at step=0 and record 500 steps
    eval_env = VecVideoRecorder(
        eval_env,
        video_folder=video_folder,
        record_video_trigger=lambda step: step == 0,
        video_length=video_length,
        name_prefix=prefix,
    )

    obs = eval_env.reset()
    for _ in range(video_length):
        action, _ = model.predict(obs, deterministic=False)
        obs, _, _, _ = eval_env.step(action)

    # Close the video recorder
    eval_env.close()

# %% [markdown]
# ## Visualize trained agent

# %%
record_video("MountainCar-v0", dqn_model, video_length=500, prefix="dqn-mountaincar")
# Out:
# objc[68002]: Class SDLApplication is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40890) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c4952c8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDLAppDelegate is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d408e0) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495318). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDLTranslatorResponder is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40958) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495390). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDLMessageBoxPresenter is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40980) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c4953b8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDL_cocoametalview is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d409d0) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495408). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDLOpenGLContext is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40a20) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495458). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDL_ShapeData is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40a98) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c4954d0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDL_CocoaClosure is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40ae8) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495520). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDL_VideoData is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40b38) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495570). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDL_WindowData is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40b88) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c4955c0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDLWindow is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40bb0) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c4955e8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class Cocoa_WindowListener is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40bd8) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495610). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDLView is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40c50) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495688). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class METAL_RenderData is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40cc8) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495700). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class METAL_TextureData is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40d18) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495750). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDL_RumbleMotor is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40d40) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c495778). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[68002]: Class SDL_RumbleContext is implemented in both /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x166d40d90) and /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x16c4957c8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# /Users/aldoglielmo/miniconda3/envs/rl312/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Saving video to /Users/aldoglielmo/EconMARL-primer-course-Sapienza/EconMARL-primer/code/L2/videos/dqn-mountaincar-step-0-to-step-500.mp4
# MoviePy - Building video /Users/aldoglielmo/EconMARL-primer-course-Sapienza/EconMARL-primer/code/L2/videos/dqn-mountaincar-step-0-to-step-500.mp4.
# MoviePy - Writing video /Users/aldoglielmo/EconMARL-primer-course-Sapienza/EconMARL-primer/code/L2/videos/dqn-mountaincar-step-0-to-step-500.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/aldoglielmo/EconMARL-primer-course-Sapienza/EconMARL-primer/code/L2/videos/dqn-mountaincar-step-0-to-step-500.mp4

# %%
show_videos("videos", prefix="dqn")
# Out:
# <video alt="videos/dqn-mountaincar-step-0-to-step-500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# ## Visualize Q-values

# %% [markdown]
# ### Exercise (5 minutes): Retrieve q-values
#
# The function will be used to retrieve the learned q-values for a given state (`observation` in the code).
#
# The q-network from SB3 DQN can be accessed via `model.q_net` and is a PyTorch module (you can therefore call `.forward()` on it).
#
# You need to convert the observation to a PyTorch tensor and then convert the resulting q-values to numpy array.
#
# Note: It is recommended to use `with th.no_grad():` context to save computation and memory

# %%
def get_q_values(model: DQN, obs: np.ndarray) -> np.ndarray:
    """
    Retrieve Q-values for a given observation.

    :param model: a DQN model
    :param obs: a single observation
    :return: the associated q-values for the given observation
    """
    assert model.get_env().observation_space.contains(obs), f"Invalid observation of shape {obs.shape}: {obs}"
    # Retrieve q-values for the given observation and convert them to numpy
    ## YOUR CODE HERE --- IGNORE ---
    obs_tensor = th.tensor(obs, device=model.device).float().unsqueeze(0)
    with th.no_grad():
        q_values = model.q_net(obs_tensor).cpu().numpy().squeeze(0)

    ## END OF YOUR CODE --- IGNORE ---
    assert isinstance(q_values, np.ndarray), "The returned q_values is not a numpy array"
    assert q_values.shape == (3,), f"Wrong shape: (3,) was expected but got {q_values.shape}"

    return q_values

# %% [markdown]
# ### Q-values for the initial state
#
# Let's reset the environment to start a new episode:

# %%
obs, _ = env.reset()

# %% [markdown]
# we plot the rendered environment to visualize it

# %%
plt.axis('off')
plt.imshow(env.render())

# %% [markdown]
# ### Exercise (5 minutes): predict taken action according to q-values
#
# Using the `get_q_values()` function, retrieve the q-values for the initial observation, print them for each action ("left", "nothing", "right") and print the action that the greedy (deterministic) policy would follow (i.e., the action with the highest q-value for that state).

# %%
action_str = ["Left", "Nothing", "Right"]  # action=0 -> go left, action=1 -> do nothing, action=2 -> go right

# %%
### YOUR CODE HERE
# Retrieve q-values for the initial state
# You should use `get_q_values()`
q_values = get_q_values(dqn_model, obs)
q_value_left, q_value_nothing, q_value_right = q_values

### END OF YOUR CODE

print(f"Q-value of the initial state left={q_value_left:.2f} nothing={q_value_nothing:.2f} right={q_value_right:.2f}")

### YOUR CODE HERE
# Compute the action taken in the initilal state according to q-values
# when following a greedy strategy
action = int(np.argmax(q_values))

## END of your code here

print(f"Action taken by the greedy policy in the initial state: {action_str[action]}")
# Out:
# Q-value of the initial state left=-67.11 nothing=-64.47 right=-63.36
# Action taken by the greedy policy in the initial state: Right

# %% [markdown]
# The q-value of the initial state corresponds to how much (discounted) reward the agent expects to get in this episode.
#
# We will compare the estimated q-value to the discounted return of the episode.

# %%
initial_q_value = q_values.max()

# %% [markdown]
# ## Step until the end of the episode

# %%
episode_rewards = []
done = False
i = 0

while not done:
    i += 1

    # Display current state
    #plt.imshow(env.render())#mode="rgb_array"))
    #plt.show()

    # Retrieve q-value
    q_values = get_q_values(dqn_model, obs)

    # Take greedy-action
    action, _ = dqn_model.predict(obs, deterministic=True)

    print(f"Q-value of the current state left={q_values[0]:.2f} nothing={q_values[1]:.2f} right={q_values[2]:.2f}")
    print(f"Action: {action_str[action]}")

    obs, reward, terminated, truncated, info = env.step(action)

    done = terminated or truncated

    episode_rewards.append(reward)
# Out:
# Q-value of the current state left=-67.11 nothing=-64.47 right=-63.36
# Action: Right
# Q-value of the current state left=-66.68 nothing=-64.02 right=-62.75
# Action: Right
# Q-value of the current state left=-66.40 nothing=-63.76 right=-62.29
# Action: Right
# Q-value of the current state left=-66.22 nothing=-63.63 right=-61.95
# Action: Right
# Q-value of the current state left=-66.11 nothing=-63.74 right=-62.02
# Action: Right
# Q-value of the current state left=-65.88 nothing=-63.74 right=-62.00
# Action: Right
# Q-value of the current state left=-64.77 nothing=-62.68 right=-60.99
# Action: Right
# Q-value of the current state left=-63.47 nothing=-61.60 right=-60.11
# Action: Right
# Q-value of the current state left=-62.36 nothing=-60.83 right=-59.61
# Action: Right
# Q-value of the current state left=-61.58 nothing=-60.26 right=-59.22
# Action: Right
# Q-value of the current state left=-60.82 nothing=-59.71 right=-58.86
# Action: Right
# Q-value of the current state left=-60.17 nothing=-59.29 right=-58.64
# Action: Right
# Q-value of the current state left=-59.60 nothing=-58.96 right=-58.51
# Action: Right
# Q-value of the current state left=-59.32 nothing=-58.96 right=-58.67
# Action: Right
# Q-value of the current state left=-59.14 nothing=-59.03 right=-58.99
# Action: Right
# Q-value of the current state left=-59.03 nothing=-59.21 right=-59.40
# Action: Left
# Q-value of the current state left=-58.77 nothing=-58.98 right=-59.20
# Action: Left
# Q-value of the current state left=-58.16 nothing=-58.30 right=-58.49
# Action: Left
# Q-value of the current state left=-56.76 nothing=-56.71 right=-56.74
# Action: Nothing
# Q-value of the current state left=-56.01 nothing=-55.97 right=-55.98
# Action: Nothing
# Q-value of the current state left=-55.55 nothing=-55.54 right=-55.52
# Action: Right
# Q-value of the current state left=-55.31 nothing=-55.32 right=-55.34
# Action: Left
# Q-value of the current state left=-55.62 nothing=-55.49 right=-55.44
# Action: Right
# Q-value of the current state left=-55.49 nothing=-55.37 right=-55.33
# Action: Right
# Q-value of the current state left=-55.38 nothing=-55.26 right=-55.22
# Action: Right
# Q-value of the current state left=-55.28 nothing=-55.16 right=-55.13
# Action: Right
# Q-value of the current state left=-55.20 nothing=-55.07 right=-55.05
# Action: Right
# Q-value of the current state left=-55.13 nothing=-54.99 right=-54.97
# Action: Right
# Q-value of the current state left=-55.01 nothing=-54.90 right=-54.93
# Action: Nothing
# Q-value of the current state left=-55.01 nothing=-54.97 right=-55.12
# Action: Nothing
# Q-value of the current state left=-55.05 nothing=-55.07 right=-55.34
# Action: Left
# Q-value of the current state left=-55.25 nothing=-55.36 right=-55.80
# Action: Left
# Q-value of the current state left=-55.49 nothing=-55.28 right=-55.54
# Action: Nothing
# Q-value of the current state left=-55.20 nothing=-55.00 right=-55.33
# Action: Nothing
# Q-value of the current state left=-54.93 nothing=-54.94 right=-55.57
# Action: Left
# Q-value of the current state left=-54.89 nothing=-54.95 right=-55.76
# Action: Left
# Q-value of the current state left=-54.93 nothing=-54.88 right=-55.69
# Action: Nothing
# Q-value of the current state left=-54.85 nothing=-54.74 right=-55.54
# Action: Nothing
# Q-value of the current state left=-54.74 nothing=-54.58 right=-55.37
# Action: Nothing
# Q-value of the current state left=-54.71 nothing=-54.54 right=-55.35
# Action: Nothing
# Q-value of the current state left=-54.88 nothing=-54.79 right=-55.66
# Action: Nothing
# Q-value of the current state left=-54.73 nothing=-54.71 right=-55.60
# Action: Nothing
# Q-value of the current state left=-54.39 nothing=-54.42 right=-55.34
# Action: Left
# Q-value of the current state left=-53.67 nothing=-53.70 right=-54.50
# Action: Left
# Q-value of the current state left=-52.96 nothing=-52.99 right=-53.70
# Action: Left
# Q-value of the current state left=-52.29 nothing=-52.34 right=-52.99
# Action: Left
# Q-value of the current state left=-51.72 nothing=-51.80 right=-52.44
# Action: Left
# Q-value of the current state left=-51.29 nothing=-51.42 right=-52.10
# Action: Left
# Q-value of the current state left=-51.03 nothing=-51.19 right=-52.03
# Action: Left
# Q-value of the current state left=-50.75 nothing=-50.94 right=-51.95
# Action: Left
# Q-value of the current state left=-50.49 nothing=-50.78 right=-51.86
# Action: Left
# Q-value of the current state left=-50.34 nothing=-50.81 right=-51.94
# Action: Left
# Q-value of the current state left=-49.29 nothing=-49.88 right=-51.02
# Action: Left
# Q-value of the current state left=-48.98 nothing=-49.65 right=-50.74
# Action: Left
# Q-value of the current state left=-48.38 nothing=-48.98 right=-50.01
# Action: Left
# Q-value of the current state left=-47.69 nothing=-48.15 right=-49.12
# Action: Left
# Q-value of the current state left=-47.07 nothing=-47.43 right=-48.32
# Action: Left
# Q-value of the current state left=-46.55 nothing=-46.89 right=-47.66
# Action: Left
# Q-value of the current state left=-46.10 nothing=-46.42 right=-47.09
# Action: Left
# Q-value of the current state left=-45.71 nothing=-46.02 right=-46.60
# Action: Left
# Q-value of the current state left=-44.70 nothing=-44.94 right=-45.26
# Action: Left
# Q-value of the current state left=-43.71 nothing=-43.88 right=-43.96
# Action: Left
# Q-value of the current state left=-42.91 nothing=-42.97 right=-42.92
# Action: Left
# Q-value of the current state left=-42.16 nothing=-42.23 right=-42.16
# Action: Right
# Q-value of the current state left=-41.84 nothing=-41.92 right=-41.79
# Action: Right
# Q-value of the current state left=-41.61 nothing=-41.69 right=-41.53
# Action: Right
# Q-value of the current state left=-41.08 nothing=-41.13 right=-40.96
# Action: Right
# Q-value of the current state left=-40.60 nothing=-40.62 right=-40.42
# Action: Right
# Q-value of the current state left=-40.06 nothing=-40.05 right=-39.84
# Action: Right
# Q-value of the current state left=-39.46 nothing=-39.41 right=-39.18
# Action: Right
# Q-value of the current state left=-38.60 nothing=-38.52 right=-38.30
# Action: Right
# Q-value of the current state left=-37.98 nothing=-37.85 right=-37.62
# Action: Right
# Q-value of the current state left=-37.96 nothing=-37.60 right=-37.34
# Action: Right
# Q-value of the current state left=-37.64 nothing=-37.19 right=-36.94
# Action: Right
# Q-value of the current state left=-37.42 nothing=-36.83 right=-36.57
# Action: Right
# Q-value of the current state left=-36.12 nothing=-35.55 right=-35.34
# Action: Right
# Q-value of the current state left=-35.27 nothing=-34.73 right=-34.50
# Action: Right
# Q-value of the current state left=-34.70 nothing=-34.10 right=-33.84
# Action: Right
# Q-value of the current state left=-34.49 nothing=-33.61 right=-33.12
# Action: Right
# Q-value of the current state left=-34.26 nothing=-33.03 right=-32.21
# Action: Right
# Q-value of the current state left=-33.10 nothing=-31.83 right=-30.87
# Action: Right
# Q-value of the current state left=-32.68 nothing=-31.19 right=-30.00
# Action: Right
# Q-value of the current state left=-32.57 nothing=-30.77 right=-29.28
# Action: Right
# Q-value of the current state left=-32.74 nothing=-30.50 right=-28.60
# Action: Right
# Q-value of the current state left=-31.78 nothing=-29.31 right=-27.25
# Action: Right
# Q-value of the current state left=-28.56 nothing=-26.25 right=-24.48
# Action: Right
# Q-value of the current state left=-26.70 nothing=-24.34 right=-22.63
# Action: Right
# Q-value of the current state left=-25.80 nothing=-23.26 right=-21.40
# Action: Right
# Q-value of the current state left=-25.73 nothing=-23.05 right=-20.83
# Action: Right
# Q-value of the current state left=-27.37 nothing=-24.36 right=-21.60
# Action: Right
# Q-value of the current state left=-28.55 nothing=-25.33 right=-22.24
# Action: Right
# Q-value of the current state left=-27.26 nothing=-24.09 right=-21.11
# Action: Right
# Q-value of the current state left=-24.98 nothing=-21.96 right=-19.24
# Action: Right
# Q-value of the current state left=-23.76 nothing=-20.80 right=-18.17
# Action: Right
# Q-value of the current state left=-22.94 nothing=-20.00 right=-17.39
# Action: Right
# Q-value of the current state left=-22.43 nothing=-19.48 right=-16.84
# Action: Right
# Q-value of the current state left=-22.20 nothing=-19.21 right=-16.49
# Action: Right
# Q-value of the current state left=-21.19 nothing=-18.33 right=-15.80
# Action: Right
# Q-value of the current state left=-20.04 nothing=-17.34 right=-15.09
# Action: Right
# Q-value of the current state left=-18.93 nothing=-16.38 right=-14.39
# Action: Right
# Q-value of the current state left=-17.66 nothing=-15.29 right=-13.57
# Action: Right
# Q-value of the current state left=-16.44 nothing=-14.22 right=-12.77
# Action: Right
# Q-value of the current state left=-15.23 nothing=-13.18 right=-11.99
# Action: Right
# Q-value of the current state left=-14.06 nothing=-12.17 right=-11.24
# Action: Right
# Q-value of the current state left=-13.10 nothing=-11.41 right=-10.70
# Action: Right
# Q-value of the current state left=-12.14 nothing=-10.66 right=-10.17
# Action: Right
# Q-value of the current state left=-11.46 nothing=-10.04 right=-9.61
# Action: Right
# Q-value of the current state left=-10.22 nothing=-8.90 right=-8.59
# Action: Right
# Q-value of the current state left=-9.01 nothing=-7.79 right=-7.61
# Action: Right
# Q-value of the current state left=-7.82 nothing=-6.71 right=-6.66
# Action: Right
# Q-value of the current state left=-6.69 nothing=-5.68 right=-5.76
# Action: Nothing
# Q-value of the current state left=-5.56 nothing=-4.65 right=-4.80
# Action: Nothing
# Q-value of the current state left=-4.13 nothing=-3.35 right=-3.62
# Action: Nothing
# Q-value of the current state left=-2.69 nothing=-2.04 right=-2.44
# Action: Nothing
# Q-value of the current state left=-1.34 nothing=-0.81 right=-1.33
# Action: Nothing

# %% [markdown]
# ### Exercise (3 minutes): compare estimated initial q-value with actual discounted return
#
# Compute the discounted return (sum of discounted reward) of the episode and compare it to the initial estimated q-value.
#
# Note: You will need to use the discount factor `dqn_model.gamma`

# %%
sum_discounted_rewards = 0

### YOUR CODE HERE
# Compute the sum of discounted reward for the last episode
# using `episode_rewards` list and `dqn_model.gamma` discount factor
for t, reward_t in enumerate(episode_rewards):
    sum_discounted_rewards += (dqn_model.gamma ** t) * reward_t

### END OF YOUR CODE

print(f"Sum discounted rewards: {sum_discounted_rewards:.2f}, initial q-value {initial_q_value:.2f}")
# Out:
# Sum discounted rewards: -68.52, initial q-value -63.36

# %% [markdown]
# ## Exercise (30 minutes): Double DQN
#
# In DQN, the same network is responsible for selecting and estimating the best next action (in the TD-target) and that may lead to over-estimation (the action which q-value is over-estimated will be chosen more often and this slow down training).
#
# To reduce over-estimation, double q-learning (and then double DQN) was proposed. It decouples the action selection from the value estimation.
#
# Concretely, in DQN, the target q-value is defined as:
#
# $$Y^{DQN}_{t} = r_{t+1} + \gamma{Q}\left(s_{t+1}, \arg\max_{a}Q\left(s_{t+1}, a; \mathbb{\theta}_{target}\right); \mathbb{\theta}_{target}\right)$$
#
# where the target network `q_net_target` with parameters $\mathbb{\theta}_{target}$ is used for both action selection and estimation, and can therefore be rewritten:
#
# $$Y^{DQN}_{t} = r_{t+1} + \gamma \max_{a}{Q}\left(s_{t+1}, a; \mathbb{\theta}_{target}\right)$$
#
# Double DQN uses the online network `q_net` with parameters $\mathbb{\theta}_{online}$ to select the action and the target network `q_net_target` to estimate the associated q-values:
#
# $$Y^{DoubleDQN}_{t} = r_{t+1} + \gamma{Q}\left(s_{t+1}, \arg\max_{a}Q\left(s_{t+1}, a; \mathbb{\theta}_{online}\right); \mathbb{\theta}_{target}\right)$$
#
#
# The goal in this exercise is for you to write the update method for `DoubleDQN`.
#
# You will need to:
#
# 1. Sample replay buffer data using `self.replay_buffer.sample(batch_size)`
#
# 2. Compute the Double DQN target q-value using the next observations `replay_data.next_observation`, the online network `self.q_net`, the target network `self.q_net_target`, the rewards `replay_data.rewards` and the termination signals `replay_data.dones`. Be careful with the shape of each object ;)
#
# 3. Compute the current q-value estimates using the online network `self.q_net`, the current observations `replay_data.observations` and the buffer actions `replay_data.actions`
#
# 4. Compute the loss to train the q-network using L2 or Huber loss (`F.smooth_l1_loss`)
#
#
# Link: https://paperswithcode.com/method/double-q-learning
#
# Paper: https://arxiv.org/abs/1509.06461

# %%
from torch.nn import functional as F

class DoubleDQN(DQN):
    def train(self, gradient_steps: int, batch_size: int = 100) -> None:
        # Switch to train mode (this affects batch norm / dropout)
        self.policy.set_training_mode(True)
        # Update learning rate according to schedule
        self._update_learning_rate(self.policy.optimizer)

        losses = []
        for _ in range(gradient_steps):
            ### YOUR CODE HERE
            # Sample replay buffer
            replay_data = ...

            # Do not backpropagate gradient to the target network
            with th.no_grad():
                # Compute the next Q-values using the target network
                next_q_values = ...
                # Decouple action selection from value estimation
                # Compute q-values for the next observation using the online q net
                next_q_values_online = ...
                # Select action with online network
                next_actions_online = ...
                # Estimate the q-values for the selected actions using target q network
                next_q_values = ...

                # 1-step TD target
                target_q_values = ...

            # Get current Q-values estimates
            current_q_values = ...

            # Retrieve the q-values for the actions from the replay buffer
            current_q_values = th.gather(current_q_values, dim=1, index=replay_data.actions.long())

            # Check the shape
            assert current_q_values.shape == target_q_values.shape

            # Compute loss (L2 or Huber loss)
            loss = ...

            ### END OF YOUR CODE

            losses.append(loss.item())

            # Optimize the q-network
            self.policy.optimizer.zero_grad()
            loss.backward()
            # Clip gradient norm
            th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
            self.policy.optimizer.step()

        # Increase update counter
        self._n_updates += gradient_steps

        self.logger.record("train/n_updates", self._n_updates, exclude="tensorboard")
        self.logger.record("train/loss", np.mean(losses))

# %% [markdown]
# ## Monitoring Evolution of the Estimated q-value
#
#
# Here we create a SB3 callback to over-estimate initial q-values and then monitor their evolution over time.

# %%
from torch.nn import functional as F

from stable_baselines3.common.callbacks import BaseCallback


class MonitorQValueCallback(BaseCallback):
    """
    Callback to monitor the evolution of the q-value
    for the initial state.
    It allows to artificially over-estimate a q-value for initial states.

    """
    def __init__(self, sample_interval: int = 2500):
        super().__init__()
        self.timesteps = []
        self.max_q_values = []
        self.sample_interval = sample_interval
        n_samples = 512
        env = gym.make("MountainCar-v0")
        # Sample initial states that will be used to monitor the estimated q-value
        self.start_obs = np.array([env.reset()[0] for _ in range(n_samples)])

    def _on_training_start(self) -> None:
        # Create overestimation
        obs = th.tensor(self.start_obs, device=self.model.device).float()
        # Over-estimate going left q-value for the initial states
        target_q_values = th.ones((len(obs), 1), device=self.model.device).float() * 100

        for _ in range(100):
            # Get current Q-values estimates
            current_q_values = self.model.q_net(obs)

            # Over-estimate going left
            current_q_values = th.gather(current_q_values, dim=1, index=th.zeros((len(obs), 1), device=self.model.device).long())

            loss = F.mse_loss(current_q_values, target_q_values)

            # Optimize the policy
            self.model.policy.optimizer.zero_grad()
            loss.backward()
            self.model.policy.optimizer.step()

    def _on_step(self) -> bool:
        # Sample q-values
        if self.n_calls % self.sample_interval == 0:
            # Monitor estimated q-values using current model
            obs = th.tensor(self.start_obs, device=self.model.device).float()
            with th.no_grad():
                q_values = self.model.q_net(obs).cpu().numpy()

            self.logger.record("train/max_q_value", float(q_values.max()))
            self.timesteps.append(self.num_timesteps)
            self.max_q_values.append(q_values.max())
        return True

# %% [markdown]
# ## Evolution of the q-value with initial over-estimation

# %% [markdown]
# ### DQN

# %%
dqn_model = DQN(
    "MlpPolicy",
    "MountainCar-v0",
    verbose=1,
    train_freq=16,
    gradient_steps=8,
    gamma=0.99,
    exploration_fraction=0.2,
    exploration_final_eps=0.07,
    target_update_interval=5000,
    learning_starts=1000,
    buffer_size=25000,
    batch_size=128,
    learning_rate=4e-3,
    policy_kwargs=dict(net_arch=[256, 256]),
    tensorboard_log=tensorboard_log,
    seed=102,
)
# Out:
# Using cpu device
# Creating environment from the given name 'MountainCar-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# Define the callback

# %%
monitor_dqn_value_cb = MonitorQValueCallback()

# %%
dqn_model.learn(total_timesteps=int(4e4), callback=monitor_dqn_value_cb)
# Out:
# Logging to data/tb/DQN_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2899     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2238     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000437 |
# |    n_updates        | 296      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1745     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00295  |
# |    n_updates        | 696      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1522     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0144   |
# |    max_q_value      | -0.696   |
# |    n_updates        | 1096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1451     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00106  |
# |    n_updates        | 1496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1446     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00329  |
# |    n_updates        | 1896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.349    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1414     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000152 |
# |    max_q_value      | -0.587   |
# |    n_updates        | 2296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1412     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 7.64e-05 |
# |    n_updates        | 2696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.163    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1398     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000492 |
# |    n_updates        | 3096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1401     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000723 |
# |    max_q_value      | -1.59    |
# |    n_updates        | 3496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1394     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00112  |
# |    n_updates        | 3896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1394     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9600     |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000258 |
# |    n_updates        | 4296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1372     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000134 |
# |    max_q_value      | -1.43    |
# |    n_updates        | 4696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1374     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000348 |
# |    n_updates        | 5096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1378     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000961 |
# |    n_updates        | 5496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1383     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 12800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00114  |
# |    max_q_value      | -2.41    |
# |    n_updates        | 5896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1386     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00525  |
# |    n_updates        | 6296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1389     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0026   |
# |    n_updates        | 6696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1392     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 15200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0112   |
# |    max_q_value      | -2.41    |
# |    n_updates        | 7096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1386     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00169  |
# |    n_updates        | 7496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1375     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 16800    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00196  |
# |    n_updates        | 7896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1356     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 17600    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000475 |
# |    max_q_value      | -3.34    |
# |    n_updates        | 8296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1330     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 18400    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00101  |
# |    n_updates        | 8696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1332     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 19200    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 7.74e-05 |
# |    n_updates        | 9096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1336     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 19981    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00116  |
# |    n_updates        | 9488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1334     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 20781    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00062  |
# |    max_q_value      | -3.4     |
# |    n_updates        | 9888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1340     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 21581    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0021   |
# |    n_updates        | 10288    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1342     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 22381    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000498 |
# |    n_updates        | 10688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1336     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23181    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0432   |
# |    max_q_value      | -4.36    |
# |    n_updates        | 11088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1338     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23981    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0714   |
# |    n_updates        | 11488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1333     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 24781    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00025  |
# |    n_updates        | 11888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1336     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 25581    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00127  |
# |    max_q_value      | -4.36    |
# |    n_updates        | 12288    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1341     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 26381    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.013    |
# |    n_updates        | 12688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1344     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 27181    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000285 |
# |    n_updates        | 13088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1342     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 27981    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000383 |
# |    max_q_value      | -4.22    |
# |    n_updates        | 13488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1346     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 28781    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00228  |
# |    n_updates        | 13888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1348     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 29581    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000286 |
# |    n_updates        | 14288    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1352     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 30381    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00361  |
# |    max_q_value      | -5.29    |
# |    n_updates        | 14688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1354     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 31181    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00137  |
# |    n_updates        | 15088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1356     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 31981    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000644 |
# |    n_updates        | 15488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1359     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 32781    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00351  |
# |    max_q_value      | -6.23    |
# |    n_updates        | 15888    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1359     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 33549    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000537 |
# |    n_updates        | 16272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1361     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 34349    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00148  |
# |    n_updates        | 16672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1364     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 35149    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.0008   |
# |    max_q_value      | -6.27    |
# |    n_updates        | 17072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1367     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 35949    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000122 |
# |    n_updates        | 17472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1370     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 36749    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000295 |
# |    n_updates        | 17872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1371     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 37549    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000202 |
# |    max_q_value      | -7.2     |
# |    n_updates        | 18272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1373     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 38349    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.00023  |
# |    n_updates        | 18672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1376     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 39149    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000114 |
# |    n_updates        | 19072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1377     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 39949    |
# | train/              |          |
# |    learning_rate    | 0.004    |
# |    loss             | 0.000464 |
# |    n_updates        | 19472    |
# ----------------------------------

# %% [markdown]
# ### Double DQN

# %%
double_q = DoubleDQN("MlpPolicy",
            "MountainCar-v0",
            verbose=1,
            train_freq=16,
            gradient_steps=8,
            gamma=0.99,
            exploration_fraction=0.2,
            exploration_final_eps=0.07,
            target_update_interval=5000,
            learning_starts=1000,
            buffer_size=25000,
            batch_size=128,
            learning_rate=4e-3,
            policy_kwargs=dict(net_arch=[256, 256]),
            tensorboard_log=tensorboard_log,
            seed=102)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 double_q = DoubleDQN("MlpPolicy",
#       2             "MountainCar-v0",
#       3             verbose=1,
#       4             train_freq=16,
#       5             gradient_steps=8,
#       6             gamma=0.99,
#       7             exploration_fraction=0.2,
#       8             exploration_final_eps=0.07,
#       9             target_update_interval=5000,
#      10             learning_starts=1000,
#      11             buffer_size=25000,
#      12             batch_size=128,
#      13             learning_rate=4e-3,
#      14             policy_kwargs=dict(net_arch=[256, 256]),
#      15             tensorboard_log=tensorboard_log,
#      16             seed=102)
#
# NameError: name 'DoubleDQN' is not defined

# %%
monitor_double_q_value_cb = MonitorQValueCallback()

# %%
double_q.learn(int(4e4), log_interval=10, callback=monitor_double_q_value_cb)

# %% [markdown]
# ### Evolution of the max q-value for start states over time

# %%
plt.figure(figsize=(6, 3), dpi=200)
plt.title("Evolution of max q-value for start states over time")
plt.plot(monitor_dqn_value_cb.timesteps, monitor_dqn_value_cb.max_q_values, label="DQN")
plt.plot(monitor_double_q_value_cb.timesteps, monitor_double_q_value_cb.max_q_values, label="Double DQN")
plt.legend()
