# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Deterministic neoclassical growth (consumption-saving) model
#
# We solve a deterministic neoclassical growth (consumption-saving) model.
#
# State: $k_t$ (current capital). Action: $k_{t+1}$ (next-period capital).
#
# Output is $y_t = k_t^{\alpha}$, consumption is residual
# $$
# c_t = k_t^{\alpha} + (1-\delta)k_t - k_{t+1},\quad c_t>0,
# $$
# and period utility is $u(c_t)=\log c_t$.
#
# The household solves
# $$
# \max_{\{k_{t+1}\}} \sum_{t=0}^{\infty} \beta^t \log(c_t).
# $$

# %% [markdown]
# ## Dynamic Programming (Value Iteration)

# %% [markdown]
# **Goal.** Compute the optimal saving rule in a deterministic neoclassical growth model via value function iteration.
#
# **State, action.** Capital $k$ on a grid; action is next capital $k'$ on the same grid.
#
# **Feasibility.**
# $$
# c = k^\alpha + (1-\delta)k - k' \ge 0,\qquad u(c)=\log(c).
# $$
#
# **Bellman equation.**
# $$
# V(k)=\max_{k'\in\mathcal K(k)} \left\{ u(c)+\beta V(k')\right\},\qquad \mathcal K(k)=\{k'\in[\underline{k},\overline{k}]: c\ge 0\}.
# $$
#
# **Value iteration (grid).**
# - Precompute $c(k,k')$ and $u(c)$ (set $-\infty$ if $c\le 0$).
# - Iterate $V^{(n+1)}(k)=\max_{k'}\{u(c)+\beta V^{(n)}(k')\}$ until convergence.
# - Store the argmax as the policy $g(k)$.

# %%
def solve_growth_vi(
    alpha=0.36,
    beta=0.96,
    delta=0.08,
    k_min=1e-3,
    k_max=50.0,
    Nk=500,
    tol=1e-8,
    maxit=10_000,
    verbose=True
):
    """
    Deterministic consumption-saving (neoclassical growth) via value iteration.
    State: k
    Action: k' chosen directly on the same grid as k
    Consumption is residual: c = k^alpha + (1-delta)k - k'
    Utility: u(c)=log(c)
    """

    # --- Grids ---
    k_grid = np.linspace(k_min, k_max, Nk)

    # production
    y = k_grid ** alpha

    # utility with log(c); infeasible => -inf
    def u(c):
        out = np.full_like(c, -np.inf, dtype=float)
        mask = c > 0.0
        out[mask] = np.log(c[mask])
        return out

    # precompute consumption matrix c_{ij} for k_i (state) and k'_j (action)
    # c[i,j] = y(k_i) + (1-delta)k_i - k'_j
    resources = y + (1.0 - delta) * k_grid                      # shape (Nk,)
    c = resources[:, None] - k_grid[None, :]                    # shape (Nk, Nk)
    U = u(c)                                                    # shape (Nk, Nk)

    # value iteration
    V = np.zeros(Nk, dtype=float)
    pol_idx = np.zeros(Nk, dtype=int)

    for it in range(1, maxit + 1):
        # RHS(i,j) = U(i,j) + beta * V(j)  (since next state is exactly k'_j)
        rhs = U + beta * V[None, :]

        # Max over actions j for each state i
        V_new = np.max(rhs, axis=1)
        pol_idx_new = np.argmax(rhs, axis=1)

        diff = np.max(np.abs(V_new - V))
        V = V_new
        pol_idx = pol_idx_new

        if verbose and (it == 1 or it % 50 == 0 or diff < tol):
            print(f"VI iter {it:5d}: sup norm diff = {diff:.3e}")

        if diff < tol:
            break

    # Recover optimal policy and implied consumption
    kp_star = k_grid[pol_idx]
    c_star = resources - kp_star

    return k_grid, V, kp_star, c_star

# %%
alpha = 0.6
beta = 0.96
delta = 1.0 # closed form solution
delta = 0.9 # numerical solution

k_dp, V_dp, kp_star_dp, c_star_dp = solve_growth_vi(
    alpha=alpha, beta=beta, delta=delta,
    k_min=1e-3, k_max=5.0, Nk=500,
    tol=1e-8, maxit=10_000, verbose=True
)
# Out:
# VI iter     1: sup norm diff = 4.203e+00
# VI iter    50: sup norm diff = 2.133e-01
# VI iter   100: sup norm diff = 2.771e-02
# VI iter   150: sup norm diff = 3.599e-03
# VI iter   200: sup norm diff = 4.674e-04
# VI iter   250: sup norm diff = 6.071e-05
# VI iter   300: sup norm diff = 7.885e-06
# VI iter   350: sup norm diff = 1.024e-06
# VI iter   400: sup norm diff = 1.330e-07
# VI iter   450: sup norm diff = 1.728e-08
# VI iter   464: sup norm diff = 9.756e-09

# %%
# the optimal policy in closed form for this model is k' = (1-alpha*beta)*k^alpha
print("\nOptimal policy in closed form: k' = (alpha*beta)*k^alpha")
optimal_kp = (alpha * beta) * k_dp ** alpha;

plt.figure(figsize=(6, 4))
plt.plot(k_dp, kp_star_dp, label="k' (next capital)")
plt.plot(k_dp, optimal_kp, label="True policy", linestyle=":")
plt.xlabel("k (current capital)")
plt.ylabel("k' (next capital)")
plt.title("Optimal Policy: k' vs k")
plt.legend()
plt.show()
# Out:
# Optimal policy in closed form: k' = (alpha*beta)*k^alpha

# %%
# Plot the value function

plt.figure(figsize=(6, 4))
plt.plot(k_dp, V_dp, label="Value Function")
plt.xlabel("k (current capital)")
plt.ylabel("V (value function)")
plt.title("Value Function: V vs k")
plt.legend()
plt.show()

# %% [markdown]
# ## Reinforcement learning (Q-learning)

# %% [markdown]
# **Goal.** Learn the saving rule with tabular Q-learning in the deterministic growth model.
#
# **State, action.** State is capital $k$ on a grid; action is an investment fraction $\iota\in(0,1)$.
#
# **Transition and reward.**
# $$
# k'=(1-\delta)k+\iota k^\alpha,\qquad c=(1-\iota)k^\alpha,\qquad r=\log(c).
# $$
#
# **Algorithm (minimal).**
# - Precompute feasible actions and $(s,a)\to s'$ plus rewards on the grid.
# - Use $\varepsilon$-greedy exploration and the TD update $Q(s,a)\leftarrow Q(s,a)+\alpha\,[r+\beta\max_{a'}Q(s',a')-Q(s,a)]$.
# - Extract the greedy policy and implied $k'$ and $c$.

# %%
def q_learning_growth_investment_fraction(
    alpha=0.36,      # production exponent
    beta=0.96,       # discount factor
    delta=0.08,      # depreciation
    k_min=1e-3,
    k_max=20.0,
    Nk=400,          # number of capital grid points (states)
    Ni=101,          # number of investment-fraction grid points (actions)
    T=300,           # steps per episode
    episodes=50000,   # number of episodes
    eps=0.10,        # epsilon-greedy exploration
    lr=0.20,         # learning rate (constant; keep simple)
    c_floor=1e-12,   # avoid log(0)
    seed=0,
    verbose=True
):
    """
    Tabular Q-learning for deterministic growth model.

    State: k on a grid (index i)
    Action: investment fraction iota in (0,1) applied to production y=k^alpha:
            invest = iota * y
            consumption = (1 - iota) * y
            k' = (1-delta)k + invest

    Reward: log(consumption)
    Transition: project k' to nearest k-grid point.
    Feasible actions at a given k are those keeping k' within [k_min, k_max]
    and consumption > 0 (enforced by iota < 1).
    """

    rng = np.random.default_rng(seed)

    # --- grids ---
    k_grid = np.linspace(k_min, k_max, Nk)
    # investment fraction in (0,1): exclude endpoints to ensure c>0 and avoid trivialities
    iota_grid = np.linspace(0.0, 1.0, Ni)
    iota_grid = iota_grid[(iota_grid > 0.0) & (iota_grid < 1.0)]
    Ni = iota_grid.size

    # precompute y(k)
    y_grid = k_grid ** alpha

    # nearest-neighbor projection to k-grid index
    def proj_idx(kp):
        kp = np.clip(kp, k_min, k_max)
        j = np.searchsorted(k_grid, kp)
        j = np.clip(j, 1, Nk - 1)
        left = k_grid[j - 1]
        right = k_grid[j]
        return j if (kp - left) > (right - kp) else (j - 1)

    # precompute feasible actions per state + transition + reward tables
    # This keeps the learning loop minimal and fast.
    next_state = np.full((Nk, Ni), -1, dtype=int)
    reward = np.full((Nk, Ni), -np.inf, dtype=float)
    feasible_actions = []

    for s in range(Nk):
        k = k_grid[s]
        y = y_grid[s]

        feas = []
        for a in range(Ni):
            iota = iota_grid[a]
            c = (1.0 - iota) * y
            if c <= c_floor:
                continue

            kp = (1.0 - delta) * k + iota * y
            if (kp < k_min) or (kp > k_max):
                continue

            sp = proj_idx(kp)
            next_state[s, a] = sp
            reward[s, a] = np.log(c)
            feas.append(a)

        # If nothing feasible (rare if grids are sensible), allow a tiny-invest fallback
        if len(feas) == 0:
            # pick smallest iota that still yields c>0 and clip kp
            a = 0
            iota = iota_grid[a]
            c = max((1.0 - iota) * y, c_floor)
            kp = np.clip((1.0 - delta) * k + iota * y, k_min, k_max)
            sp = proj_idx(kp)
            next_state[s, a] = sp
            reward[s, a] = np.log(c)
            feas = [a]

        feasible_actions.append(np.array(feas, dtype=int))

    # --- Q table ---
    Q = np.zeros((Nk, Ni), dtype=float)

    # training
    for ep in range(1, episodes + 1):
        
        # random initial state (uniform on grid)
        s = int(rng.integers(0, Nk))

        for t in range(T):
            feas = feasible_actions[s]

            # epsilon-greedy over feasible actions only
            if rng.random() < eps:
                a = int(rng.choice(feas))
            else:
                a = int(feas[np.argmax(Q[s, feas])])

            sp = next_state[s, a]
            r = reward[s, a]

            # Q-learning update (deterministic transition)
            td_target = r + beta * np.max(Q[sp, feasible_actions[sp]])
            Q[s, a] += lr * (td_target - Q[s, a])

            s = sp

        if verbose and (ep == 1 or ep % 1000 == 0 or ep == episodes):
            # crude progress indicator: average greedy value proxy
            greedy_actions = np.array([feasible_actions[i][np.argmax(Q[i, feasible_actions[i]])] for i in range(Nk)])
            avg_r = np.mean([reward[i, greedy_actions[i]] for i in range(Nk)])
            print(f"Episode {ep:5d}/{episodes}: avg immediate reward under greedy policy ~ {avg_r:.4f}")

    # extract greedy policy
    pol_a = np.array([feasible_actions[s][np.argmax(Q[s, feasible_actions[s]])] for s in range(Nk)], dtype=int)
    iota_star = iota_grid[pol_a]

    # implied policy in k' and c
    k_star = k_grid
    y_star = y_grid
    c_star = (1.0 - iota_star) * y_star
    kp_star = (1.0 - delta) * k_star + iota_star * y_star

    return k_grid, Q, iota_star, c_star, kp_star

# %%
alpha = 0.6
beta = 0.96
delta = 1.0 # closed form solution

k_rl, Q_rl, iota_star_rl, c_star_rl, kp_star_rl = q_learning_growth_investment_fraction(
    alpha=alpha, beta=beta, delta=delta,
    k_min=1e-3, k_max=5.0, Nk=50, Ni=51,
    T=100, episodes=500_000,
    eps=0.10, lr=0.10,
    seed=0, verbose=True
)
# Out:
# Episode     1/500000: avg immediate reward under greedy policy ~ 0.2855
# Episode  1000/500000: avg immediate reward under greedy policy ~ -0.4710
# Episode  2000/500000: avg immediate reward under greedy policy ~ -0.9536
# Episode  3000/500000: avg immediate reward under greedy policy ~ -1.2341
# Episode  4000/500000: avg immediate reward under greedy policy ~ -1.2457
# Episode  5000/500000: avg immediate reward under greedy policy ~ -1.1553
# Episode  6000/500000: avg immediate reward under greedy policy ~ -0.8102
# Episode  7000/500000: avg immediate reward under greedy policy ~ -1.0091
# Episode  8000/500000: avg immediate reward under greedy policy ~ -0.8077
# Episode  9000/500000: avg immediate reward under greedy policy ~ -0.9073
# Episode 10000/500000: avg immediate reward under greedy policy ~ -0.9269
# Episode 11000/500000: avg immediate reward under greedy policy ~ -0.8188
# Episode 12000/500000: avg immediate reward under greedy policy ~ -0.7013
# Episode 13000/500000: avg immediate reward under greedy policy ~ -0.9220
# Episode 14000/500000: avg immediate reward under greedy policy ~ -0.9661
# Episode 15000/500000: avg immediate reward under greedy policy ~ -0.6496
# Episode 16000/500000: avg immediate reward under greedy policy ~ -0.7487
# Episode 17000/500000: avg immediate reward under greedy policy ~ -0.6210
# Episode 18000/500000: avg immediate reward under greedy policy ~ -0.6116
# Episode 19000/500000: avg immediate reward under greedy policy ~ -0.7394
# Episode 20000/500000: avg immediate reward under greedy policy ~ -0.8396
# Episode 21000/500000: avg immediate reward under greedy policy ~ -0.4918
# Episode 22000/500000: avg immediate reward under greedy policy ~ -0.7930
# Episode 23000/500000: avg immediate reward under greedy policy ~ -0.6011
# Episode 24000/500000: avg immediate reward under greedy policy ~ -0.4500
# Episode 25000/500000: avg immediate reward under greedy policy ~ -0.7053
# Episode 26000/500000: avg immediate reward under greedy policy ~ -0.6036
# Episode 27000/500000: avg immediate reward under greedy policy ~ -0.6591
# Episode 28000/500000: avg immediate reward under greedy policy ~ -0.7133
# Episode 29000/500000: avg immediate reward under greedy policy ~ -0.7405
# Episode 30000/500000: avg immediate reward under greedy policy ~ -0.4787
# Episode 31000/500000: avg immediate reward under greedy policy ~ -0.7177
# Episode 32000/500000: avg immediate reward under greedy policy ~ -0.4122
# Episode 33000/500000: avg immediate reward under greedy policy ~ -0.5450
# Episode 34000/500000: avg immediate reward under greedy policy ~ -0.5182
# Episode 35000/500000: avg immediate reward under greedy policy ~ -0.5467
# Episode 36000/500000: avg immediate reward under greedy policy ~ -0.5390
# Episode 37000/500000: avg immediate reward under greedy policy ~ -0.4558
# Episode 38000/500000: avg immediate reward under greedy policy ~ -0.4624
# Episode 39000/500000: avg immediate reward under greedy policy ~ -0.4560
# Episode 40000/500000: avg immediate reward under greedy policy ~ -0.6662
# Episode 41000/500000: avg immediate reward under greedy policy ~ -0.6670
# Episode 42000/500000: avg immediate reward under greedy policy ~ -0.5662
# Episode 43000/500000: avg immediate reward under greedy policy ~ -0.5342
# Episode 44000/500000: avg immediate reward under greedy policy ~ -0.5805
# Episode 45000/500000: avg immediate reward under greedy policy ~ -0.4186
# Episode 46000/500000: avg immediate reward under greedy policy ~ -0.6240
# Episode 47000/500000: avg immediate reward under greedy policy ~ -0.7246
# Episode 48000/500000: avg immediate reward under greedy policy ~ -0.4966
# Episode 49000/500000: avg immediate reward under greedy policy ~ -0.6292
# Episode 50000/500000: avg immediate reward under greedy policy ~ -0.4542
# Episode 51000/500000: avg immediate reward under greedy policy ~ -0.5646
# Episode 52000/500000: avg immediate reward under greedy policy ~ -0.5456
# Episode 53000/500000: avg immediate reward under greedy policy ~ -0.4670
# Episode 54000/500000: avg immediate reward under greedy policy ~ -0.6900
# Episode 55000/500000: avg immediate reward under greedy policy ~ -0.4348
# Episode 56000/500000: avg immediate reward under greedy policy ~ -0.4903
# Episode 57000/500000: avg immediate reward under greedy policy ~ -0.3403
# Episode 58000/500000: avg immediate reward under greedy policy ~ -0.5343
# Episode 59000/500000: avg immediate reward under greedy policy ~ -0.4299
# Episode 60000/500000: avg immediate reward under greedy policy ~ -0.5974
# Episode 61000/500000: avg immediate reward under greedy policy ~ -0.4914
# Episode 62000/500000: avg immediate reward under greedy policy ~ -0.4749
# Episode 63000/500000: avg immediate reward under greedy policy ~ -0.5612
# Episode 64000/500000: avg immediate reward under greedy policy ~ -0.5805
# Episode 65000/500000: avg immediate reward under greedy policy ~ -0.5811
# Episode 66000/500000: avg immediate reward under greedy policy ~ -0.5080
# Episode 67000/500000: avg immediate reward under greedy policy ~ -0.4799
# Episode 68000/500000: avg immediate reward under greedy policy ~ -0.4873
# Episode 69000/500000: avg immediate reward under greedy policy ~ -0.4476
# Episode 70000/500000: avg immediate reward under greedy policy ~ -0.5179
# Episode 71000/500000: avg immediate reward under greedy policy ~ -0.4127
# Episode 72000/500000: avg immediate reward under greedy policy ~ -0.5229
# Episode 73000/500000: avg immediate reward under greedy policy ~ -0.3314
# Episode 74000/500000: avg immediate reward under greedy policy ~ -0.4194
# Episode 75000/500000: avg immediate reward under greedy policy ~ -0.5851
# Episode 76000/500000: avg immediate reward under greedy policy ~ -0.4809
# Episode 77000/500000: avg immediate reward under greedy policy ~ -0.3661
# Episode 78000/500000: avg immediate reward under greedy policy ~ -0.5643
# Episode 79000/500000: avg immediate reward under greedy policy ~ -0.4833
# Episode 80000/500000: avg immediate reward under greedy policy ~ -0.5909
# Episode 81000/500000: avg immediate reward under greedy policy ~ -0.5581
# Episode 82000/500000: avg immediate reward under greedy policy ~ -0.5086
# Episode 83000/500000: avg immediate reward under greedy policy ~ -0.3901
# Episode 84000/500000: avg immediate reward under greedy policy ~ -0.4010
# Episode 85000/500000: avg immediate reward under greedy policy ~ -0.4798
# Episode 86000/500000: avg immediate reward under greedy policy ~ -0.5534
# Episode 87000/500000: avg immediate reward under greedy policy ~ -0.3450
# Episode 88000/500000: avg immediate reward under greedy policy ~ -0.5163
# Episode 89000/500000: avg immediate reward under greedy policy ~ -0.5229
# Episode 90000/500000: avg immediate reward under greedy policy ~ -0.5449
# Episode 91000/500000: avg immediate reward under greedy policy ~ -0.4556
# Episode 92000/500000: avg immediate reward under greedy policy ~ -0.4617
# Episode 93000/500000: avg immediate reward under greedy policy ~ -0.4557
# Episode 94000/500000: avg immediate reward under greedy policy ~ -0.4828
# Episode 95000/500000: avg immediate reward under greedy policy ~ -0.3461
# Episode 96000/500000: avg immediate reward under greedy policy ~ -0.5175
# Episode 97000/500000: avg immediate reward under greedy policy ~ -0.4141
# Episode 98000/500000: avg immediate reward under greedy policy ~ -0.4565
# Episode 99000/500000: avg immediate reward under greedy policy ~ -0.4945
# Episode 100000/500000: avg immediate reward under greedy policy ~ -0.4030
# Episode 101000/500000: avg immediate reward under greedy policy ~ -0.4212
# Episode 102000/500000: avg immediate reward under greedy policy ~ -0.4695
# Episode 103000/500000: avg immediate reward under greedy policy ~ -0.4327
# Episode 104000/500000: avg immediate reward under greedy policy ~ -0.3836
# Episode 105000/500000: avg immediate reward under greedy policy ~ -0.4446
# Episode 106000/500000: avg immediate reward under greedy policy ~ -0.4429
# Episode 107000/500000: avg immediate reward under greedy policy ~ -0.5004
# Episode 108000/500000: avg immediate reward under greedy policy ~ -0.4204
# Episode 109000/500000: avg immediate reward under greedy policy ~ -0.4969
# Episode 110000/500000: avg immediate reward under greedy policy ~ -0.4796
# Episode 111000/500000: avg immediate reward under greedy policy ~ -0.4125
# Episode 112000/500000: avg immediate reward under greedy policy ~ -0.4126
# Episode 113000/500000: avg immediate reward under greedy policy ~ -0.4551
# Episode 114000/500000: avg immediate reward under greedy policy ~ -0.4286
# Episode 115000/500000: avg immediate reward under greedy policy ~ -0.4665
# Episode 116000/500000: avg immediate reward under greedy policy ~ -0.3934
# Episode 117000/500000: avg immediate reward under greedy policy ~ -0.3737
# Episode 118000/500000: avg immediate reward under greedy policy ~ -0.4398
# Episode 119000/500000: avg immediate reward under greedy policy ~ -0.4586
# Episode 120000/500000: avg immediate reward under greedy policy ~ -0.4383
# Episode 121000/500000: avg immediate reward under greedy policy ~ -0.4568
# Episode 122000/500000: avg immediate reward under greedy policy ~ -0.3965
# Episode 123000/500000: avg immediate reward under greedy policy ~ -0.3872
# Episode 124000/500000: avg immediate reward under greedy policy ~ -0.4023
# Episode 125000/500000: avg immediate reward under greedy policy ~ -0.3969
# Episode 126000/500000: avg immediate reward under greedy policy ~ -0.4197
# Episode 127000/500000: avg immediate reward under greedy policy ~ -0.4166
# Episode 128000/500000: avg immediate reward under greedy policy ~ -0.4170
# Episode 129000/500000: avg immediate reward under greedy policy ~ -0.4224
# Episode 130000/500000: avg immediate reward under greedy policy ~ -0.4120
# Episode 131000/500000: avg immediate reward under greedy policy ~ -0.4099
# Episode 132000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 133000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 134000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 135000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 136000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 137000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 138000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 139000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 140000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 141000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 142000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 143000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 144000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 145000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 146000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 147000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 148000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 149000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 150000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 151000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 152000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 153000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 154000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 155000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 156000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 157000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 158000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 159000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 160000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 161000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 162000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 163000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 164000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 165000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 166000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 167000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 168000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 169000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 170000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 171000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 172000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 173000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 174000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 175000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 176000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 177000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 178000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 179000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 180000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 181000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 182000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 183000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 184000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 185000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 186000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 187000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 188000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 189000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 190000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 191000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 192000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 193000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 194000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 195000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 196000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 197000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 198000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 199000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 200000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 201000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 202000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 203000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 204000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 205000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 206000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 207000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 208000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 209000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 210000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 211000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 212000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 213000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 214000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 215000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 216000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 217000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 218000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 219000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 220000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 221000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 222000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 223000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 224000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 225000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 226000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 227000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 228000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 229000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 230000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 231000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 232000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 233000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 234000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 235000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 236000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 237000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 238000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 239000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 240000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 241000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 242000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 243000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 244000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 245000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 246000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 247000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 248000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 249000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 250000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 251000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 252000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 253000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 254000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 255000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 256000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 257000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 258000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 259000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 260000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 261000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 262000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 263000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 264000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 265000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 266000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 267000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 268000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 269000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 270000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 271000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 272000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 273000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 274000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 275000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 276000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 277000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 278000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 279000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 280000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 281000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 282000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 283000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 284000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 285000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 286000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 287000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 288000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 289000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 290000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 291000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 292000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 293000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 294000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 295000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 296000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 297000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 298000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 299000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 300000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 301000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 302000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 303000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 304000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 305000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 306000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 307000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 308000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 309000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 310000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 311000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 312000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 313000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 314000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 315000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 316000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 317000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 318000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 319000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 320000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 321000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 322000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 323000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 324000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 325000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 326000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 327000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 328000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 329000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 330000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 331000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 332000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 333000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 334000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 335000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 336000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 337000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 338000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 339000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 340000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 341000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 342000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 343000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 344000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 345000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 346000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 347000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 348000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 349000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 350000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 351000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 352000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 353000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 354000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 355000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 356000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 357000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 358000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 359000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 360000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 361000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 362000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 363000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 364000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 365000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 366000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 367000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 368000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 369000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 370000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 371000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 372000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 373000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 374000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 375000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 376000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 377000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 378000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 379000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 380000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 381000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 382000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 383000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 384000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 385000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 386000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 387000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 388000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 389000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 390000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 391000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 392000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 393000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 394000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 395000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 396000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 397000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 398000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 399000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 400000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 401000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 402000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 403000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 404000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 405000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 406000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 407000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 408000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 409000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 410000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 411000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 412000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 413000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 414000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 415000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 416000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 417000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 418000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 419000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 420000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 421000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 422000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 423000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 424000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 425000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 426000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 427000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 428000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 429000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 430000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 431000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 432000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 433000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 434000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 435000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 436000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 437000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 438000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 439000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 440000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 441000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 442000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 443000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 444000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 445000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 446000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 447000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 448000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 449000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 450000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 451000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 452000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 453000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 454000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 455000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 456000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 457000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 458000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 459000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 460000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 461000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 462000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 463000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 464000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 465000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 466000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 467000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 468000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 469000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 470000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 471000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 472000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 473000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 474000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 475000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 476000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 477000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 478000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 479000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 480000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 481000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 482000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 483000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 484000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 485000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 486000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 487000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 488000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 489000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 490000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 491000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 492000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 493000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 494000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 495000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 496000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 497000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 498000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 499000/500000: avg immediate reward under greedy policy ~ -0.4152
# Episode 500000/500000: avg immediate reward under greedy policy ~ -0.4152

# %%
# compute closed form optimal policy for comparison: iota* = alpha*beta, c* = (1-iota)*y, k' = (1-delta)*k + iota*y
iota_star_closed = alpha * beta

y_grid = k_rl ** alpha
kp_star_closed = iota_star_closed * y_grid 
    
# Plot the policy
plt.figure(figsize=(6, 4))
plt.plot(k_rl, kp_star_rl, label="k' (next capital)")
plt.plot(k_rl, kp_star_closed, label="True policy", linestyle=":")
plt.xlabel("k (current capital)")
plt.ylabel("k' (next capital)")
plt.title("Learned Policy: Next Capital vs Current Capital")
plt.legend()
plt.grid()
plt.show()

# %%
# # plot value function (max Q) vs k
# feasible_actions = [np.where(Q_rl[s] > -np.inf)[0] for s in range(len(k_rl))]
# V_rl = np.array([np.max(Q_rl[s, feasible_actions[s]]) for s in range(len(k_rl))])

# plt.figure(figsize=(6, 4))
# plt.plot(k_rl, V_rl, label="RL Value Function (max Q)")
# plt.plot(k_dp, V_dp, label="DP Value Function", linestyle=":")
# plt.xlabel("k (current capital)")
# plt.ylabel("Value")
# plt.title("Value Function vs Current Capital")
# plt.legend()
# plt.grid()
# plt.show()
